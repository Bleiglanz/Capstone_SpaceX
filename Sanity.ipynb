# %%
import pandas as pd
df1 = pd.read_csv('owncsv/own_work_dataset_part_1.csv')

# %%
df1.head()
# Out:
#    FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1  2010-06-04       Falcon 9  6123.547647   LEO  CCSFS SLC 40
# 1             2  2012-05-22       Falcon 9   525.000000   LEO  CCSFS SLC 40
# 2             3  2013-03-01       Falcon 9   677.000000   ISS  CCSFS SLC 40
# 3             4  2013-09-29       Falcon 9   500.000000    PO   VAFB SLC 4E
# 4             5  2013-12-03       Falcon 9  3170.000000   GTO  CCSFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs         LandingPad  Block  \
# 0    None None        1     False   False  False  6123.547647058824    1.0
# 1    None None        1     False   False  False  6123.547647058824    1.0
# 2    None None        1     False   False  False  6123.547647058824    1.0
# 3  False Ocean        1     False   False  False  6123.547647058824    1.0
# 4    None None        1     False   False  False  6123.547647058824    1.0
#
#    ReusedCount Serial   Longitude   Latitude
# ...

# %%
df2 = pd.read_csv('owncsv/own_work_spacex_web_scraped.csv')

# %%
df2.head(90)
# Out:
#     Flight No. Launch site                               Payload  \
# 0            1       CCAFS  Dragon Spacecraft Qualification Unit
# 1            2       CCAFS                                Dragon
# 2            3       CCAFS                                Dragon
# 3            4       CCAFS                          SpaceX CRS-1
# 4            5       CCAFS                          SpaceX CRS-2
# ..         ...         ...                                   ...
# 85          86       CCAFS                              Starlink
# 86          87       CCAFS                              Starlink
# 87          88       CCAFS                               GPS III
# 88          89       CCAFS                             ANASIS-II
# 89          90         KSC                              Starlink
#
#       Payload mass Orbit  Customer Launch outcome Version Booster  \
# 0                0   LEO       NaN      Success\n  F9 v1.0B0003.1
# ...

# %%
df1.describe()
# Out:
#        FlightNumber   PayloadMass    Flights      Block  ReusedCount  \
# count     90.000000     90.000000  90.000000  90.000000    90.000000
# mean      45.500000   6123.547647   1.788889   3.500000     3.000000
# std       26.124701   4732.115291   1.213172   1.595288     3.827752
# min        1.000000    350.000000   1.000000   1.000000     0.000000
# 25%       23.250000   2510.750000   1.000000   2.000000     0.000000
# 50%       45.500000   4701.500000   1.000000   4.000000     1.000000
# 75%       67.750000   8912.750000   2.000000   5.000000     4.000000
# max       90.000000  15600.000000   6.000000   5.000000    11.000000
#
#         Longitude   Latitude
# count   90.000000  90.000000
# mean   -86.366477  29.449963
# std     14.149518   2.141306
# min   -120.610829  28.561857
# 25%    -80.603956  28.561857
# 50%    -80.577366  28.561857
# 75%    -80.577366  28.608058
# max    -80.577366  34.632093
